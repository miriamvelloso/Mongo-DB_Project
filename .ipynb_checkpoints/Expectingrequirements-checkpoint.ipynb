# %%
from pymongo import MongoClient
import geojson
import requests
import os
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import json
import re

# %% [markdown]
# # Con geocode buscaremos las cordenadas del centro de San Francismo

# %%
def geocode(address):
    res = requests.get(f"https://geocode.xyz/{address}", params={"json":1})
    data = res.json()
    return {
        "type":"Point",
        "coordinates":[float(data["longt"]),float(data["latt"])]
    }

# %%
geocode("san francisco")
# Out:
# {'type': 'Point', 'coordinates': [-122.40438, 37.66873]}

# %% [markdown]
# # Buscamos aquellas empresas valoradas en más de 1 millón de $

# %%
dbName = "Crunchbase_Dataset"
mongodbURL = f"mongodb://localhost/{dbName}"
print(mongodbURL)
client = MongoClient(mongodbURL, connectTimeoutMS=2000,serverSelectionTimeoutMS=2000)
db = client.get_database()
# Out:
# mongodb://localhost/Crunchbase_Dataset

# %%
with open("output/gaming_companies.json") as f:
  data = json.load(f)

# %%
df = pd.DataFrame(data)
df
# Out:
#                              name total_money_raised           description  \
# 0                         Ustream             $60.1M  San Francisco Office
# 1                       Revision3                $9M                    HQ
# 2                          CastTV              $3.1M                  None
# 3                        Metacafe               $50M
# 4                            IODA                 $0                  None
# 5                           Mevio             $48.9M
# 6                         Rupture                $3M          Headquarters
# 7                           Kabam              $125M                    HQ
# 8                  Citizen Sports               $10M
# 9                     Soundflavor              $5.8M                  None
# 10                       Scavenja                 $0
# 11                         ngmoco             $44.8M        Secret Factory
# 12  Shattered Reality Interactive              $1.1M           Main Office
# 13  Shattered Reality Interactive              $1.1M           Main Office
# 14                         Booyah             $59.5M           Booyah Inc.
# 15                        GotGame                $1M            GotGame HQ
# 16             Unity Technologies             $17.5M             US Office
#
#                           address1    address2 zip_code           city  \
# 0                     410 Townsend   Suite 400    94107  San Francisco
# 1                      2415 3rd St                94107  San Francisco
# 2                  374 Brannan St.        None    94107  San Francisco
# 3                  128 King Street   3rd Floor    94107  San Francisco
# 4     539 Bryant Street, Suite 303        None    94107  San Francisco
# 5             577 2nd St Suite 203                94107  San Francisco
# 6                   400 2nd Street   Suite 350    94107  San Francisco
# 7                795 Folsom Street   Suite 600    94107  San Francisco
# 8                   525 Brannan St                94107  San Francisco
# 9     2339 Third Street, 4th Floor                94107  San Francisco
# 10                 539 Bryant St.,   Suite 402    94107  San Francisco
# 11                185 Berry Street  Suite 3000    94107  San Francisco
# 12                  490 2nd Street   Suite 100    94107  San Francisco
# 13                  490 2nd Street   Suite 100    94107  San Francisco
# 14  139 Townsend Street, 3rd Floor                94107  San Francisco
# 15                 1 Bluxome Place   Suite 204    94107  San Francisco
# 16                      795 Folsom                94107  San Francisco
#
#    state_code country_code   latitude   longitude
# 0          CA          USA  37.392936 -122.079480
# 1          CA          USA  37.757758 -122.388243
# 2          CA          USA  37.780716 -122.393913
# 3          CA          USA  37.437328 -122.159928
# 4          CA          USA  37.780134 -122.396744
# 5          CA          USA  37.782263 -122.392142
# 6          CA          USA  37.783898 -122.395234
# 7          CA          USA  37.394456 -122.078531
# 8          CA          USA  37.777513 -122.397044
# 9          CA          USA        NaN         NaN
# 10         CA          USA  37.780134 -122.396744
# 11         CA          USA  37.770510 -122.401581
# 12         CA          USA  37.783046 -122.394067
# 13         CA          USA  37.783046 -122.394067
# 14         CA          USA  37.420728 -122.210341
# 15         CA          USA  37.777720 -122.395785
# 16         CA          USA  55.692461   12.530107

# %%
df['total_money_raised'].dtype
# Out:
# dtype('O')

# %%
df['total_money_raised']
# Out:
# 0     $60.1M
# 1        $9M
# 2      $3.1M
# 3       $50M
# 4         $0
# 5     $48.9M
# 6        $3M
# 7      $125M
# 8       $10M
# 9      $5.8M
# 10        $0
# 11    $44.8M
# 12     $1.1M
# 13     $1.1M
# 14    $59.5M
# 15       $1M
# 16    $17.5M
# Name: total_money_raised, dtype: object

# %%
df['total_money_raised'] = df['total_money_raised'].str.replace('$', '').str.replace('M', '').astype(float)
df
# Out:
#                              name  total_money_raised           description  \
# 0                         Ustream                60.1  San Francisco Office
# 1                       Revision3                 9.0                    HQ
# 2                          CastTV                 3.1                  None
# 3                        Metacafe                50.0
# 4                            IODA                 0.0                  None
# 5                           Mevio                48.9
# 6                         Rupture                 3.0          Headquarters
# 7                           Kabam               125.0                    HQ
# 8                  Citizen Sports                10.0
# 9                     Soundflavor                 5.8                  None
# 10                       Scavenja                 0.0
# 11                         ngmoco                44.8        Secret Factory
# 12  Shattered Reality Interactive                 1.1           Main Office
# 13  Shattered Reality Interactive                 1.1           Main Office
# 14                         Booyah                59.5           Booyah Inc.
# 15                        GotGame                 1.0            GotGame HQ
# 16             Unity Technologies                17.5             US Office
#
#                           address1    address2 zip_code           city  \
# 0                     410 Townsend   Suite 400    94107  San Francisco
# 1                      2415 3rd St                94107  San Francisco
# 2                  374 Brannan St.        None    94107  San Francisco
# 3                  128 King Street   3rd Floor    94107  San Francisco
# 4     539 Bryant Street, Suite 303        None    94107  San Francisco
# 5             577 2nd St Suite 203                94107  San Francisco
# 6                   400 2nd Street   Suite 350    94107  San Francisco
# 7                795 Folsom Street   Suite 600    94107  San Francisco
# 8                   525 Brannan St                94107  San Francisco
# 9     2339 Third Street, 4th Floor                94107  San Francisco
# 10                 539 Bryant St.,   Suite 402    94107  San Francisco
# 11                185 Berry Street  Suite 3000    94107  San Francisco
# 12                  490 2nd Street   Suite 100    94107  San Francisco
# 13                  490 2nd Street   Suite 100    94107  San Francisco
# 14  139 Townsend Street, 3rd Floor                94107  San Francisco
# 15                 1 Bluxome Place   Suite 204    94107  San Francisco
# 16                      795 Folsom                94107  San Francisco
#
#    state_code country_code   latitude   longitude
# 0          CA          USA  37.392936 -122.079480
# 1          CA          USA  37.757758 -122.388243
# 2          CA          USA  37.780716 -122.393913
# 3          CA          USA  37.437328 -122.159928
# 4          CA          USA  37.780134 -122.396744
# 5          CA          USA  37.782263 -122.392142
# 6          CA          USA  37.783898 -122.395234
# 7          CA          USA  37.394456 -122.078531
# 8          CA          USA  37.777513 -122.397044
# 9          CA          USA        NaN         NaN
# 10         CA          USA  37.780134 -122.396744
# 11         CA          USA  37.770510 -122.401581
# 12         CA          USA  37.783046 -122.394067
# 13         CA          USA  37.783046 -122.394067
# 14         CA          USA  37.420728 -122.210341
# 15         CA          USA  37.777720 -122.395785
# 16         CA          USA  55.692461   12.530107

# %%
df_over_1 = df.loc[df['total_money_raised'] >= 1]
df_over_1
# Out:
#                              name  total_money_raised           description  \
# 0                         Ustream                True  San Francisco Office
# 1                       Revision3                True                    HQ
# 2                          CastTV                True                  None
# 3                        Metacafe                True
# 5                           Mevio                True
# 6                         Rupture                True          Headquarters
# 7                           Kabam                True                    HQ
# 8                  Citizen Sports                True
# 9                     Soundflavor                True                  None
# 11                         ngmoco                True        Secret Factory
# 12  Shattered Reality Interactive                True           Main Office
# 13  Shattered Reality Interactive                True           Main Office
# 14                         Booyah                True           Booyah Inc.
# 15                        GotGame                True            GotGame HQ
# 16             Unity Technologies                True             US Office
#
#                           address1    address2 zip_code           city  \
# 0                     410 Townsend   Suite 400    94107  San Francisco
# 1                      2415 3rd St                94107  San Francisco
# 2                  374 Brannan St.        None    94107  San Francisco
# 3                  128 King Street   3rd Floor    94107  San Francisco
# 5             577 2nd St Suite 203                94107  San Francisco
# 6                   400 2nd Street   Suite 350    94107  San Francisco
# 7                795 Folsom Street   Suite 600    94107  San Francisco
# 8                   525 Brannan St                94107  San Francisco
# 9     2339 Third Street, 4th Floor                94107  San Francisco
# 11                185 Berry Street  Suite 3000    94107  San Francisco
# 12                  490 2nd Street   Suite 100    94107  San Francisco
# 13                  490 2nd Street   Suite 100    94107  San Francisco
# 14  139 Townsend Street, 3rd Floor                94107  San Francisco
# 15                 1 Bluxome Place   Suite 204    94107  San Francisco
# 16                      795 Folsom                94107  San Francisco
#
#    state_code country_code   latitude   longitude
# 0          CA          USA  37.392936 -122.079480
# 1          CA          USA  37.757758 -122.388243
# 2          CA          USA  37.780716 -122.393913
# 3          CA          USA  37.437328 -122.159928
# 5          CA          USA  37.782263 -122.392142
# 6          CA          USA  37.783898 -122.395234
# 7          CA          USA  37.394456 -122.078531
# 8          CA          USA  37.777513 -122.397044
# 9          CA          USA        NaN         NaN
# 11         CA          USA  37.770510 -122.401581
# 12         CA          USA  37.783046 -122.394067
# 13         CA          USA  37.783046 -122.394067
# 14         CA          USA  37.420728 -122.210341
# 15         CA          USA  37.777720 -122.395785
# 16         CA          USA  55.692461   12.530107

# %%
df_over_1.to_json("output/developrequirements.json", orient = "records" )

# %% [markdown]
# # Primer requerimiento será buscar aeropuertos cercanos para los Account Managers

# %%
def getFromApi(path,queryParams=dict(),apiKey=""):
    url=f"https://maps.googleapis.com/maps/api{path}"
    headers = {"Authorization":f"token {apiKey}"} if apiKey else {}
    res = requests.get(url, params=queryParams, headers=headers)
    print(res.status_code)
    return res.json()

# %%
queryParams = {
    "location": "37.7790262, -122.4199061",
    "radius": "10000",
    "type": " International Airport",
    "keyword": "Airport",
    "key":"AIzaSyAGr5E3StLQi9t7r-E-wxc77hOKh708gKE"
   
}

result=getFromApi("/place/nearbysearch/json",queryParams, apiKey="AIzaSyAGr5E3StLQi9t7r-E-wxc77hOKh708gKE")
# Out:
# 200

# %%
result
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7909427, 'lng': -122.4084994},
#     'viewport': {'northeast': {'lat': 37.79240107989271,
#       'lng': -122.4071642201073},
#      'southwest': {'lat': 37.78970142010727, 'lng': -122.4098638798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png',
#    'id': '25261e6ab74b888fda8074958524eb4bd2030335',
#    'name': 'Design To Win Foundation',
#    'place_id': 'ChIJAQAAQIyAhYARFyzn8XrbmI0',
#    'rating': 3,
#    'reference': 'ChIJAQAAQIyAhYARFyzn8XrbmI0',
#    'scope': 'GOOGLE',
#    'types': ['airport', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7484859, 'lng': -122.4976407},
#     'viewport': {'northeast': {'lat': 37.74983572989272,
#       'lng': -122.4962908701073},
#      'southwest': {'lat': 37.74713607010728, 'lng': -122.4989905298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png',
#    'id': '60046ae1cae59dc33f7db315016c500a4bcde39d',
#    'name': 'West Sunset RC Flying Field',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116578730298088036916">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAVfGUT2FvFfLkmo3MLTJaNl6rT9dIXHbOvAq7MtT6lPpQHrizXIM7e6g1KHYMrZLXb721jI1v1q5-NNIsmyLJF0OHxblckkITdr1gvLIizTskCBxRZVtUkLC8psIvwUeoEhCFvtvpJXeR5LQryl-KibOeGhThyptzNGjluDd0i8HHlHSa7XdaDw',
#      'width': 4032}],
#    'place_id': 'ChIJQ_RlHbWHhYAR2tceaPTKSwQ',
#    'plus_code': {'compound_code': 'PGX2+9W Outer Sunset, San Francisco, CA, United States',
#     'global_code': '849VPGX2+9W'},
#    'rating': 5,
#    'reference': 'ChIJQ_RlHbWHhYAR2tceaPTKSwQ',
#    'scope': 'GOOGLE',
#    'types': ['airport', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7857289, 'lng': -122.4104463},
#     'viewport': {'northeast': {'lat': 37.78727607989272,
#       'lng': -122.4091347701073},
#      'southwest': {'lat': 37.78457642010727, 'lng': -122.4118344298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png',
#    'id': 'be894cd1e6df96915800421753811b40f8808b4e',
#    'name': 'SFO',
#    'place_id': 'ChIJ6R4tfYiBhYAR0V2Pjd7kYaw',
#    'plus_code': {'compound_code': 'QHPQ+7R Tenderloin, San Francisco, CA, United States',
#     'global_code': '849VQHPQ+7R'},
#    'rating': 5,
#    'reference': 'ChIJ6R4tfYiBhYAR0V2Pjd7kYaw',
#    'scope': 'GOOGLE',
#    'types': ['airport', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': "333 O'Farrell St, San Francisco"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.766902, 'lng': -122.419558},
#     'viewport': {'northeast': {'lat': 37.76822117989272,
#       'lng': -122.4183634701073},
#      'southwest': {'lat': 37.76552152010728, 'lng': -122.4210631298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png',
#    'id': '9dc9887895af61129ee74817598c814227610b79',
#    'name': 'MUrgency Inc. (Airport Assistance; Tech Innovation Incubator; & Quaternary Referral Clinics)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 901,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110372022711561055492">MUrgency Inc.</a>'],
#      'photo_reference': 'CmRaAAAAVjTvOxbmiPrjVOrvqrtNVyW42NKr7Y5p_nrqjmixU2PvMOrjL7t3OUIqEZQpWMRgg1VaN9V3IAN27kP9bBOG8pSishVGVnJ1K0HKqDrM3431Y3DXR8p3QFMwSeKucbLnEhCs2kXHXTQnv0zLyuSZk754GhTg1wzdDFdRukWHT6u7rmVqqUxS3Q',
#      'width': 901}],
#    'place_id': 'ChIJD6jcmYaAhYARTdmZqQPPs5E',
#    'plus_code': {'compound_code': 'QH8J+Q5 Mission District, San Francisco, CA, United States',
#     'global_code': '849VQH8J+Q5'},
#    'rating': 5,
#    'reference': 'ChIJD6jcmYaAhYARTdmZqQPPs5E',
#    'scope': 'GOOGLE',
#    'types': ['airport', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Impact Hub, 1885 Mission St E6, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7666109, 'lng': -122.3903809},
#     'viewport': {'northeast': {'lat': 37.76781852989272,
#       'lng': -122.3891703201073},
#      'southwest': {'lat': 37.76511887010728, 'lng': -122.3918699798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png',
#    'id': 'd3859264b679a029b06bed82b4134069e1d58acb',
#    'name': 'UCSF Helipad',
#    'place_id': 'ChIJVVIh3ZJ_j4ARvDV7dYyC3u4',
#    'plus_code': {'compound_code': 'QJ85+JR Potrero Hill, San Francisco, CA, United States',
#     'global_code': '849VQJ85+JR'},
#    'rating': 0,
#    'reference': 'ChIJVVIh3ZJ_j4ARvDV7dYyC3u4',
#    'scope': 'GOOGLE',
#    'types': ['airport', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '1825 4th St, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7788907, 'lng': -122.402358},
#     'viewport': {'northeast': {'lat': 37.78019747989273,
#       'lng': -122.4009150201073},
#      'southwest': {'lat': 37.77749782010729, 'lng': -122.4036146798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'abfd9dd175dd26436b5df41abeb0ffede8f5ea05',
#    'name': 'Airport Express',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 382,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102885790538328411799">Airport Express</a>'],
#      'photo_reference': 'CmRaAAAAq6RalSoYtYoGzR2Zf7IVK_jBya5HdXT7DBZFd7TsWUsAQ3_WROpi52fSYDBhmg9N5RLSm93K_I7-_AL16tixTU_r7cDd-7Jxjbd7pro1jLuTEttcWHEBK079lqli_IPCEhArT12r9v42o88QVQdn_yRFGhTuPydxo9iPX9NaYoVHJyhdEAq9BQ',
#      'width': 600}],
#    'place_id': 'ChIJjXN7boCAhYARLFobZnAe-1E',
#    'plus_code': {'compound_code': 'QHHX+H3 SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHHX+H3'},
#    'rating': 2.2,
#    'reference': 'ChIJjXN7boCAhYARLFobZnAe-1E',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 66,
#    'vicinity': '910 Harrison St, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7318451, 'lng': -122.3883588},
#     'viewport': {'northeast': {'lat': 37.73311097989272,
#       'lng': -122.3870873701073},
#      'southwest': {'lat': 37.73041132010728, 'lng': -122.3897870298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '8feda9bf23a8a0ad20552edff75a11e55de14b6e',
#    'name': 'Airport Now',
#    'place_id': 'ChIJX1kAXxB_j4ARNxZXHnjKHyU',
#    'plus_code': {'compound_code': 'PJJ6+PM Bayview, San Francisco, CA, United States',
#     'global_code': '849VPJJ6+PM'},
#    'rating': 0,
#    'reference': 'ChIJX1kAXxB_j4ARNxZXHnjKHyU',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '1524 Quesada Ave, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7005292, 'lng': -122.4072251},
#     'viewport': {'northeast': {'lat': 37.70184117989272,
#       'lng': -122.4060241201073},
#      'southwest': {'lat': 37.69914152010728, 'lng': -122.4087237798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '8ecf1534d95198352e7c005cc4e0e619e4671451',
#    'name': 'Bayporter Express Airport Shtl',
#    'place_id': 'ChIJuyfDbdN-j4ARcP1WgcI1q5s',
#    'plus_code': {'compound_code': 'PH2V+64 Brisbane, California, United States',
#     'global_code': '849VPH2V+64'},
#    'rating': 2,
#    'reference': 'ChIJuyfDbdN-j4ARcP1WgcI1q5s',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '27 Industrial Way, Brisbane'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7837143, 'lng': -122.4197824},
#     'viewport': {'northeast': {'lat': 37.78519642989272,
#       'lng': -122.4184783201073},
#      'southwest': {'lat': 37.78249677010728, 'lng': -122.4211779798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'a2a815b2355633e91a339fd6e72a379959df1591',
#    'name': 'American Airporter Shuttle',
#    'photos': [{'height': 2880,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106048594040559266687">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAbJeNiEYaPkQqtc0e9row3S3Ukh4B9jznK09Dhb79ShxIx1gIJN_h_Pgr1ZOFBVp_c9fEJ1JETOUCYjjreYS1BCo_m59n4m4mULqUCynmKQSXt3aIG6MKg1TYHnTV_C_zEhDHYtiAo33WA8AoCVtdjT7IGhSv5WIDtxhCHxeb6aCMN71tF-FxHQ',
#      'width': 4320}],
#    'place_id': 'ChIJA_KsGJeAhYARj4a5L3P2iZ8',
#    'plus_code': {'compound_code': 'QHMJ+F3 Tenderloin, San Francisco, CA, United States',
#     'global_code': '849VQHMJ+F3'},
#    'rating': 1.8,
#    'reference': 'ChIJA_KsGJeAhYARj4a5L3P2iZ8',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 40,
#    'vicinity': '819 Ellis St, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.766869, 'lng': -122.4196054},
#     'viewport': {'northeast': {'lat': 37.76820467989272,
#       'lng': -122.4183871701073},
#      'southwest': {'lat': 37.76550502010728, 'lng': -122.4210868298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '118aa1f002fc505b5b0fdb27189b9504dfb2dcd7',
#    'name': 'MUrgency Airport Assistance',
#    'place_id': 'ChIJq6r65iN-j4AR2Zaj7wE0Cl4',
#    'plus_code': {'compound_code': 'QH8J+P5 Mission District, San Francisco, CA, United States',
#     'global_code': '849VQH8J+P5'},
#    'rating': 0,
#    'reference': 'ChIJq6r65iN-j4AR2Zaj7wE0Cl4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '1885 Mission St, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7796104, 'lng': -122.4033898},
#     'viewport': {'northeast': {'lat': 37.78091427989271,
#       'lng': -122.4019824201072},
#      'southwest': {'lat': 37.77821462010727, 'lng': -122.4046820798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '04cc3c5695c4743766f381d2e701bb8bcccb97bd',
#    'name': 'SFO Shuttle',
#    'place_id': 'ChIJ78AQ94CAhYARGom-IddiQkE',
#    'plus_code': {'compound_code': 'QHHW+RJ SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHHW+RJ'},
#    'rating': 5,
#    'reference': 'ChIJ78AQ94CAhYARGom-IddiQkE',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '210 Shipley, San Francisco'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 37.7622688, 'lng': -122.4070662},
#     'viewport': {'northeast': {'lat': 37.76361092989272,
#       'lng': -122.4057716701072},
#      'southwest': {'lat': 37.76091127010728, 'lng': -122.4084713298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '692634a9238070b5f85a232ecc7819692e1e6ecd',
#    'name': 'Pacific Airport Shuttle',
#    'place_id': 'ChIJ5X8MWDF-j4AR_QedunUrWKU',
#    'plus_code': {'compound_code': 'QH6V+W5 Mission District, San Francisco, CA, United States',
#     'global_code': '849VQH6V+W5'},
#    'rating': 0,
#    'reference': 'ChIJ5X8MWDF-j4AR_QedunUrWKU',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'San Francisco'}],
#  'status': 'OK'}

# %%
airport_list = []
for r in result['results']:
    airport_list.append({
        "Requirement":"Airport",
        "name":r["name"],
        "latitude":r["geometry"]["location"]["lat"],
        "longitude":r["geometry"]["location"]["lng"],
        "location":{"type":"Point","coordinates": [r["geometry"]["location"]["lat"],r["geometry"]["location"]["lng"]]}})

df = pd.DataFrame(airport_list)
df
# Out:
#    Requirement                                               name   latitude  \
# 0      Airport                           Design To Win Foundation  37.790943
# 1      Airport                        West Sunset RC Flying Field  37.748486
# 2      Airport                                                SFO  37.785729
# 3      Airport  MUrgency Inc. (Airport Assistance; Tech Innova...  37.766902
# 4      Airport                                       UCSF Helipad  37.766611
# 5      Airport                                    Airport Express  37.778891
# 6      Airport                                        Airport Now  37.731845
# 7      Airport                     Bayporter Express Airport Shtl  37.700529
# 8      Airport                         American Airporter Shuttle  37.783714
# 9      Airport                        MUrgency Airport Assistance  37.766869
# 10     Airport                                        SFO Shuttle  37.779610
# 11     Airport                            Pacific Airport Shuttle  37.762269
#
#      longitude                                           location
# 0  -122.408499  {'type': 'Point', 'coordinates': [37.7909427, ...
# 1  -122.497641  {'type': 'Point', 'coordinates': [37.7484859, ...
# 2  -122.410446  {'type': 'Point', 'coordinates': [37.7857289, ...
# 3  -122.419558  {'type': 'Point', 'coordinates': [37.766902, -...
# 4  -122.390381  {'type': 'Point', 'coordinates': [37.7666109, ...
# 5  -122.402358  {'type': 'Point', 'coordinates': [37.7788907, ...
# 6  -122.388359  {'type': 'Point', 'coordinates': [37.7318451, ...
# 7  -122.407225  {'type': 'Point', 'coordinates': [37.7005292, ...
# 8  -122.419782  {'type': 'Point', 'coordinates': [37.7837143, ...
# 9  -122.419605  {'type': 'Point', 'coordinates': [37.766869, -...
# 10 -122.403390  {'type': 'Point', 'coordinates': [37.7796104, ...
# 11 -122.407066  {'type': 'Point', 'coordinates': [37.7622688, ...

# %%
df.to_json("output/airport_details.json", orient="records" )

# %% [markdown]
# # Buscaremos restaurantes veganos cercas para el CEO/Presidente

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id='CLIENT_ID',
client_secret='CLIENT_SECRET',
v='20180323',
ll='40.7243,-74.0018',
query='coffee',
limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
def getfromfoursquare(coordinates,distance,name,category):
    url = 'https://api.foursquare.com/v2/venues/explore'
    params = dict(
     client_id= 'RAABSTSZVIQ0Z1P1ETWTERFAAPISOPN0W2F0SOYYQLXPK2DE',
     client_secret='31TNFQXZR0EWLQJQ3VGRSFAZSDWBWMRWQ3SAIORDQMLDWU1N',
     v='20200627',
     ll=coordinates,
     query=name,
     categoryId= category
    )
    
    resp = requests.get(url=url, params=params)
    data = json.loads(resp.text)
    return

# %%
getfromfoursquare("37.7790262, -122.4199061",1000,"School", "4bf58dd8d48988d13b941735")

# %%
def getFromFoursquare(coordinates,distance,name,category):
    url = 'https://api.foursquare.com/v2/venues/explore'
    params = dict(
    client_id="RAABSTSZVIQ0Z1P1ETWTERFAAPISOPN0W2F0SOYYQLXPK2DE",
    client_secret="31TNFQXZR0EWLQJQ3VGRSFAZSDWBWMRWQ3SAIORDQMLDWU1N",
    v='20200417',
    ll= coordinates,
    radius= distance,
    query= name,
    categoryId= category,
    )
    resp = requests.get(url=url, params=params)
    return resp.json()

# %%
vegan_result=getFromFoursquare("37.7790262, -122.4199061",3000,"Vegan Restaurant","4bf58dd8d48988d1d3941735")

# %%
vegan_result
# Out:
# {'meta': {'code': 200, 'requestId': '5ef721b73b1954422f9639a0'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'San Francisco',
#   'headerFullLocation': 'San Francisco',
#   'headerLocationGranularity': 'city',
#   'query': 'vegan restaurant',
#   'totalResults': 45,
#   'suggestedBounds': {'ne': {'lat': 37.806026227000025,
#     'lng': -122.38580903529598},
#    'sw': {'lat': 37.75202617299997, 'lng': -122.45400316470403}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a0cb0fff964a52056751fe3',
#        'name': 'Ananda Fuara',
#        'location': {'address': '1298 Market St',
#         'crossStreet': 'at Larkin St',
#         'lat': 37.77769251469199,
#         'lng': -122.41635331222618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77769251469199,
#           'lng': -122.41635331222618},
#          {'label': 'entrance', 'lat': 37.777874, 'lng': -122.416118}],
#         'distance': 346,
#         'postalCode': '94102',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1298 Market St (at Larkin St)',
#          'San Francisco, CA 94102',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '326205',
#         'url': 'https://www.grubhub.com/restaurant/ananda-fuara-1298-market-st-san-francisco/326205?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=326205',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a0cb0fff964a52056751fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '547a3a09498edded45384099',
#        'name': 'Golden Era Vegan',
#        'location': {'address': '395 Golden Gate Ave',
#         'lat': 37.78149473910515,
#         'lng': -122.41682231651436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78149473910515,
#           'lng': -122.41682231651436},
#          {'label': 'entrance', 'lat': 37.781406, 'lng': -122.416781}],
#         'distance': 386,
#         'postalCode': '94102',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['395 Golden Gate Ave',
#          'San Francisco, CA 94102',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2212124',
#         'url': 'https://www.grubhub.com/restaurant/golden-era-vegan-restaurant-395-golden-gate-avesan-francisco-ca-94102-san-francisco/2212124?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2212124',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-547a3a09498edded45384099-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54c42de4498ee52a43a5ee44',
#        'name': 'The Flying Falafel',
#        'location': {'address': '1051 Market St',
#         'crossStreet': 'at 6th St',
#         'lat': 37.781323,
#         'lng': -122.411138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.781323,
#           'lng': -122.411138}],
#         'distance': 812,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1051 Market St (at 6th St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '416494',
#         'url': 'https://www.grubhub.com/restaurant/the-flying-falafel-1051-market-st-san-francisco/416494?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=416494',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54c42de4498ee52a43a5ee44-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5914e8fae1f0aa603aa3c369',
#        'name': "Ike's Sandwiches",
#        'location': {'address': '901 Polk St',
#         'lat': 37.78514559764317,
#         'lng': -122.4196290626362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78514559764317,
#           'lng': -122.4196290626362}],
#         'distance': 681,
#         'postalCode': '94109',
#         'cc': 'US',
#         'neighborhood': 'Tenderloin',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 Polk St',
#          'San Francisco, CA 94109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '471753',
#         'url': 'https://www.grubhub.com/restaurant/ikes-love--sandwiches-901-polk-st-san-francisco/471753?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=471753',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5914e8fae1f0aa603aa3c369-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54a8b5d1498ef8abe40ce6b3',
#        'name': 'Shizen',
#        'location': {'address': '370 14th St',
#         'crossStreet': 'at Stevenson St',
#         'lat': 37.76819038843062,
#         'lng': -122.42162728988704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.76819038843062,
#           'lng': -122.42162728988704}],
#         'distance': 1215,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['370 14th St (at Stevenson St)',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54a8b5d1498ef8abe40ce6b3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59cb288d6c08d172265a8e6d',
#        'name': 'Chisme',
#        'location': {'address': '882 Sutter St',
#         'crossStreet': 'Leavenworth St',
#         'lat': 37.78846715609786,
#         'lng': -122.41480239709736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78846715609786,
#           'lng': -122.41480239709736}],
#         'distance': 1142,
#         'postalCode': '94109',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['882 Sutter St (Leavenworth St)',
#          'San Francisco, CA 94109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59cb288d6c08d172265a8e6d-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4955ccf964a520b86d26e3',
#        'name': 'Gracias Madre',
#        'location': {'address': '2211 Mission St',
#         'crossStreet': 'at 18th St',
#         'lat': 37.761484,
#         'lng': -122.419144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.761484,
#           'lng': -122.419144},
#          {'label': 'entrance', 'lat': 37.761538, 'lng': -122.419211}],
#         'distance': 1953,
#         'postalCode': '94110',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2211 Mission St (at 18th St)',
#          'San Francisco, CA 94110',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '316828',
#         'url': 'https://www.grubhub.com/restaurant/gracias-madre-2211-mission-st-san-francisco/316828?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=316828',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '117486637'}},
#       'referralId': 'e-0-4b4955ccf964a520b86d26e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7d7aebf5b9644b441e28f3',
#        'name': 'Thai Idea Vegetarian Restaurant',
#        'location': {'address': '710 Polk St',
#         'crossStreet': 'at Eddy St',
#         'lat': 37.783395,
#         'lng': -122.419141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.783395,
#           'lng': -122.419141},
#          {'label': 'entrance', 'lat': 37.783462, 'lng': -122.419141}],
#         'distance': 490,
#         'postalCode': '94109',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['710 Polk St (at Eddy St)',
#          'San Francisco, CA 94109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1121680',
#         'url': 'https://www.grubhub.com/restaurant/thai-idea-vegetarian-710-polk-st-san-francisco/1121680?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1121680',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7d7aebf5b9644b441e28f3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52473397498ef94edc534492',
#        'name': 'Hella Vegan Eats',
#        'location': {'address': 'On the go!',
#         'lat': 37.770232781504006,
#         'lng': -122.41399998333559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.770232781504006,
#           'lng': -122.41399998333559}],
#         'distance': 1108,
#         'cc': 'US',
#         'state': 'California',
#         'country': 'United States',
#         'formattedAddress': ['On the go!', 'California', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52473397498ef94edc534492-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '44ccee85f964a52016361fe3',
#        'name': 'Cha-Ya Vegetarian Japanese Restaurant',
#        'location': {'address': '762 Valencia St',
#         'crossStreet': 'btwn 18th & 19th St',
#         'lat': 37.760786300576164,
#         'lng': -122.42155699648818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.760786300576164,
#           'lng': -122.42155699648818},
#          {'label': 'entrance', 'lat': 37.760749, 'lng': -122.421635}],
#         'distance': 2035,
#         'postalCode': '94110',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['762 Valencia St (btwn 18th & 19th St)',
#          'San Francisco, CA 94110',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42338233'}},
#       'referralId': 'e-0-44ccee85f964a52016361fe3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57fbb40ecd1057f331ffd3e3',
#        'name': 'sweetgreen',
#        'location': {'address': '171 2nd St',
#         'lat': 37.7872625,
#         'lng': -122.3986346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7872625,
#           'lng': -122.3986346}],
#         'distance': 2083,
#         'postalCode': '94105',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['171 2nd St',
#          'San Francisco, CA 94105',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1033919',
#         'url': 'https://www.grubhub.com/restaurant/sweetgreen-171-2nd-st-san-francisco/1033919?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1033919',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57fbb40ecd1057f331ffd3e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d77246152f4a00007528cb9',
#        'name': 'Wildseed',
#        'location': {'address': '2000 Union St',
#         'lat': 37.7976259,
#         'lng': -122.4324404,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.7976259,
#           'lng': -122.4324404}],
#         'distance': 2345,
#         'postalCode': '94123',
#         'cc': 'US',
#         'neighborhood': 'Union Street',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2000 Union St',
#          'San Francisco, CA 94123',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d77246152f4a00007528cb9-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58af46d1951e7d0a6394102b',
#        'name': 'Vegan Picnic',
#        'location': {'address': '1977 Union St',
#         'crossStreet': 'Buchanan',
#         'lat': 37.79749028773226,
#         'lng': -122.43174840879858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79749028773226,
#           'lng': -122.43174840879858}],
#         'distance': 2304,
#         'postalCode': '94123',
#         'cc': 'US',
#         'neighborhood': 'Union Street',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1977 Union St (Buchanan)',
#          'San Francisco, CA 94123',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58af46d1951e7d0a6394102b-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49dad092f964a520b25e1fe3',
#        'name': 'Udupi Palace',
#        'location': {'address': '1007 Valencia St',
#         'crossStreet': 'at 21st St',
#         'lat': 37.75676871020177,
#         'lng': -122.42108520192178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.75676871020177,
#           'lng': -122.42108520192178},
#          {'label': 'entrance', 'lat': 37.756717, 'lng': -122.420981}],
#         'distance': 2479,
#         'postalCode': '94110',
#         'cc': 'US',
#         'neighborhood': 'Mission District',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1007 Valencia St (at 21st St)',
#          'San Francisco, CA 94110',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1969527',
#         'url': 'https://www.grubhub.com/restaurant/udupi-palace-1007-valencia-st-san-francisco/1969527?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1969527',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49dad092f964a520b25e1fe3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b391baef964a520605625e3',
#        'name': 'Enjoy Vegetarian Restaurant',
#        'location': {'address': '839 Kearny St',
#         'crossStreet': 'at Washington St.',
#         'lat': 37.79583330118931,
#         'lng': -122.40509327113475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79583330118931,
#           'lng': -122.40509327113475}],
#         'distance': 2280,
#         'postalCode': '94108',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['839 Kearny St (at Washington St.)',
#          'San Francisco, CA 94108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '316707',
#         'url': 'https://www.grubhub.com/restaurant/enjoy-vegetarian-restaurant-839-kearny-st-san-francisco/316707?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=316707',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b391baef964a520605625e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a03132af964a52087711fe3',
#        'name': 'Mixt',
#        'location': {'address': '560 Mission St',
#         'crossStreet': 'btwn 1st & 2nd',
#         'lat': 37.788844,
#         'lng': -122.399149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.788844,
#           'lng': -122.399149}],
#         'distance': 2128,
#         'postalCode': '94105',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['560 Mission St (btwn 1st & 2nd)',
#          'San Francisco, CA 94105',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a03132af964a52087711fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55bec3d8498ea0833a1c10b7',
#        'name': 'VeganBurg',
#        'location': {'address': '1466 Haight St',
#         'lat': 37.77015576494585,
#         'lng': -122.4465223090921,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.77015576494585,
#           'lng': -122.4465223090921}],
#         'distance': 2541,
#         'postalCode': '94117',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1466 Haight St',
#          'San Francisco, CA 94117',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '346280',
#         'url': 'https://www.grubhub.com/restaurant/veganburg-1466-haight-st-san-francisco/346280?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=346280',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55bec3d8498ea0833a1c10b7-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49b5c9cef964a52002531fe3',
#        'name': 'Good Life Grocery',
#        'location': {'address': '1524 20th St',
#         'crossStreet': 'at Connecticut St',
#         'lat': 37.760060051464905,
#         'lng': -122.3967928465983,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.760060051464905,
#           'lng': -122.3967928465983},
#          {'label': 'entrance', 'lat': 37.760086, 'lng': -122.396827}],
#         'distance': 2931,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1524 20th St (at Connecticut St)',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49b5c9cef964a52002531fe3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58d971cce18e6505fb03201b',
#        'name': 'Mixt',
#        'location': {'address': '51 Yerba Buena Ln',
#         'lat': 37.78575139510038,
#         'lng': -122.40412370868718,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.78575139510038,
#           'lng': -122.40412370868718},
#          {'label': 'entrance', 'lat': 37.78549, 'lng': -122.404906}],
#         'distance': 1577,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['51 Yerba Buena Ln',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58d971cce18e6505fb03201b-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58d2eede102f47386fe2e7e3',
#        'name': 'Nourish Cafe',
#        'location': {'address': '1030 Hyde St',
#         'crossStreet': 'Btw Pine & California Sts',
#         'lat': 37.79052853432049,
#         'lng': -122.41729615432375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79052853432049,
#           'lng': -122.41729615432375}],
#         'distance': 1300,
#         'postalCode': '94109',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1030 Hyde St (Btw Pine & California Sts)',
#          'San Francisco, CA 94109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '396504',
#         'url': 'https://www.grubhub.com/restaurant/nourish-cafe-1030-hyde-st-san-francisco/396504?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=396504',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58d2eede102f47386fe2e7e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4460d56ef964a5200b331fe3',
#        'name': 'Love N Haight',
#        'location': {'address': '553 Haight St',
#         'crossStreet': 'btwn Fillmore & Steiner',
#         'lat': 37.771968742479416,
#         'lng': -122.43130243391766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.771968742479416,
#           'lng': -122.43130243391766},
#          {'label': 'entrance', 'lat': 37.771914, 'lng': -122.431324}],
#         'distance': 1273,
#         'postalCode': '94117',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['553 Haight St (btwn Fillmore & Steiner)',
#          'San Francisco, CA 94117',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1831748',
#         'url': 'https://www.grubhub.com/restaurant/love-n-haight-553-haight-street-san-francisco/1831748?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1831748',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4460d56ef964a5200b331fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b80b2dfb3d8e2002cc06a42',
#        'name': 'Next Level Burger',
#        'location': {'address': '450 Rhode Island St',
#         'lat': 37.76474624603116,
#         'lng': -122.40272744689193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.76474624603116,
#           'lng': -122.40272744689193}],
#         'distance': 2193,
#         'postalCode': '94107',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['450 Rhode Island St',
#          'San Francisco, CA 94107',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1148621',
#         'url': 'https://www.grubhub.com/restaurant/next-level-burger---san-francisco-450-rhode-island-st-san-francisco/1148621?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1148621',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b80b2dfb3d8e2002cc06a42-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa8ad88f964a520b35120e3',
#        'name': 'The Plant',
#        'location': {'address': '3352 Steiner St',
#         'crossStreet': 'at Chestnut St',
#         'lat': 37.80047667669209,
#         'lng': -122.43774459333486,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.80047667669209,
#           'lng': -122.43774459333486}],
#         'distance': 2857,
#         'postalCode': '94123',
#         'cc': 'US',
#         'neighborhood': 'Marina District',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['3352 Steiner St (at Chestnut St)',
#          'San Francisco, CA 94123',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa8ad88f964a520b35120e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548614e1498e76066a49a098',
#        'name': 'Urban Remedy',
#        'location': {'address': '1957 Union St',
#         'crossStreet': 'Buchanan',
#         'lat': 37.797553811980684,
#         'lng': -122.43149687600089,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.797553811980684,
#           'lng': -122.43149687600089}],
#         'distance': 2300,
#         'postalCode': '94123',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1957 Union St (Buchanan)',
#          'San Francisco, CA 94123',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1598340',
#         'url': 'https://www.grubhub.com/restaurant/urban-remedy-1957-union-street-san-francisco/1598340?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1598340',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548614e1498e76066a49a098-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56098c7a498e84bc593495a4',
#        'name': 'Elixiria',
#        'location': {'address': '25 Beale St',
#         'lat': 37.792053,
#         'lng': -122.396844,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.792053,
#           'lng': -122.396844},
#          {'label': 'entrance', 'lat': 37.792576, 'lng': -122.396075}],
#         'distance': 2493,
#         'postalCode': '94105',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['25 Beale St',
#          'San Francisco, CA 94105',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56098c7a498e84bc593495a4-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563d1b6ecd1073c835e14047',
#        'name': 'The Plant Cafe Organic',
#        'location': {'address': '250 Montgomery St.',
#         'crossStreet': 'Pine St.',
#         'lat': 37.79188755556935,
#         'lng': -122.40249870982906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79188755556935,
#           'lng': -122.40249870982906}],
#         'distance': 2096,
#         'postalCode': '94104',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['250 Montgomery St. (Pine St.)',
#          'San Francisco, CA 94104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563d1b6ecd1073c835e14047-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0dc7609cceef3b9e446ce2',
#        'name': 'The Plant Cafe Organic',
#        'location': {'address': '101 California St',
#         'crossStreet': 'at Pine St.',
#         'lat': 37.79252480866014,
#         'lng': -122.39846488908981,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79252480866014,
#           'lng': -122.39846488908981}],
#         'distance': 2411,
#         'postalCode': '94111',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['101 California St (at Pine St.)',
#          'San Francisco, CA 94111',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0dc7609cceef3b9e446ce2-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5478dda9498eb17c04ef2290',
#        'name': 'Indochine',
#        'location': {'address': '508 Valencia St',
#         'crossStreet': '16th St',
#         'lat': 37.76468916550355,
#         'lng': -122.42196627450242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.76468916550355,
#           'lng': -122.42196627450242}],
#         'distance': 1606,
#         'postalCode': '94110',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['508 Valencia St (16th St)',
#          'San Francisco, CA 94110',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '561630',
#         'url': 'https://www.grubhub.com/restaurant/indochine-vegan-508-valencia-st-san-francisco/561630?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=561630',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5478dda9498eb17c04ef2290-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b3f908a6336be002cfd72db',
#        'name': 'Mr.East Kitchen',
#        'location': {'address': '276 5th St',
#         'lat': 37.780451517462836,
#         'lng': -122.40378102356958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.780451517462836,
#           'lng': -122.40378102356958}],
#         'distance': 1427,
#         'postalCode': '94103',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['276 5th St',
#          'San Francisco, CA 94103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '931893',
#         'url': 'https://www.grubhub.com/restaurant/mr-east-kitchen-276-fifth-st-san-francisco/931893?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=931893',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '505195699'}},
#       'referralId': 'e-0-5b3f908a6336be002cfd72db-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a91b13cf964a520611b20e3',
#        'name': 'Lucky Creation Restaurant',
#        'location': {'address': '854 Washington St',
#         'crossStreet': 'btwn Stockton & Ross',
#         'lat': 37.79505604072138,
#         'lng': -122.40727052445759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.79505604072138,
#           'lng': -122.40727052445759},
#          {'label': 'entrance', 'lat': 37.795105, 'lng': -122.407406}],
#         'distance': 2102,
#         'postalCode': '94108',
#         'cc': 'US',
#         'city': 'San Francisco',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['854 Washington St (btwn Stockton & Ross)',
#          'San Francisco, CA 94108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a91b13cf964a520611b20e3-29'}]}]}}

# %%
vegan_list=[]
for e in vegan_result["response"]["groups"]:
    for i in e["items"]:
        vegan_name=i['venue']["name"]
        vegan_latitud=i['venue']["location"]["lat"]
        vegan_longitud=i['venue']["location"]["lng"]
        vegan_list.append({"Requirement":"Vegan Restaurant","name":vegan_name,"latitude":vegan_latitud,"longitude":vegan_longitud,"location":{"type":"Point","coordinates":[vegan_longitud,vegan_latitud]}})

# %%
df_vegan = pd.DataFrame(vegan_list)
df_vegan.head()
# Out:
#         Requirement                name   latitude   longitude  \
# 0  Vegan Restaurant        Ananda Fuara  37.777693 -122.416353
# 1  Vegan Restaurant    Golden Era Vegan  37.781495 -122.416822
# 2  Vegan Restaurant  The Flying Falafel  37.781323 -122.411138
# 3  Vegan Restaurant    Ike's Sandwiches  37.785146 -122.419629
# 4  Vegan Restaurant              Shizen  37.768190 -122.421627
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [-122.4163533...
# 1  {'type': 'Point', 'coordinates': [-122.4168223...
# 2  {'type': 'Point', 'coordinates': [-122.411138,...
# 3  {'type': 'Point', 'coordinates': [-122.4196290...
# 4  {'type': 'Point', 'coordinates': [-122.4216272...

# %%
df_vegan.to_json("output/vegan_info.json", orient="records")

# %% [markdown]
# # Bucaremos colegios para los hijos de los trabajadores

# %%
schools = getFromFoursquare("37.7790262, -122.4199061",3000,"School","4f4533804b9074f6e4fb0105")

# %%
school_list=[]
for e in schools["response"]["groups"]:
    for i in e["items"]:
        name=i['venue']["name"]
        latitud=i['venue']["location"]["lat"]
        longitud=i['venue']["location"]["lng"]
        school_list.append({"Requirement":"School","name":name,"latitude":latitud,"longitude":longitud,"location":{"type":"Point","coordinates":[longitud,latitud]}})

# %%
df_school = pd.DataFrame(school_list)
df_school
# Out:
#    Requirement                                        name   latitude  \
# 0       School    John Swett Alternative Elementary School  37.780412
# 1       School       Chinese American International School  37.775275
# 2       School                        Mission Dolores Park  37.759990
# 3       School                        C5 Children's School  37.778864
# 4       School                 John Muir Elementary School  37.773624
# 5       School                Rosa Parks Elementary School  37.782909
# 6       School                Spring Valley Science School  37.794436
# 7       School                   Redding Elementary School  37.789690
# 8       School         Bessie Carmichael Elementary School  37.776266
# 9       School                  McKinley Elementary School  37.767186
# 10      School                         Marshall Elementary  37.766302
# 11      School                Creative Arts Charter School  37.779772
# 12      School                   Cathedral School for Boys  37.792128
# 13      School                     Mission Dolores Academy  37.764560
# 14      School                 Schools of the Sacred Heart  37.794496
# 15      School              Ecole Notre Dame des Victoires  37.791159
# 16      School                     Gordon J Lau Elementary  37.794044
# 17      School                   Sanchez Elementary School  37.763723
# 18      School                  William L. Cobb Elementary  37.787460
# 19      School                      Nam Kue Chinese School  37.793196
# 20      School                        Stuart Hall for Boys  37.794467
# 21      School                          Sherman Elementary  37.798012
# 22      School                           The New School SF  37.760324
# 23      School                      Jean Parker Elementary  37.797641
# 24      School         Edwin and Anita Lee Newcomer School  37.794781
# 25      School  Chinese Education Center Elementary School  37.794757
# 26      School                        Town School for Boys  37.792041
# 27      School                San Francisco Waldorf School  37.790777
# 28      School                Hillwood Academic Day School  37.793320
# 29      School                  St. Vincent De Paul School  37.796049
#
#      longitude                                           location
# 0  -122.422916  {'type': 'Point', 'coordinates': [-122.4229159...
# 1  -122.422111  {'type': 'Point', 'coordinates': [-122.4221108...
# 2  -122.427118  {'type': 'Point', 'coordinates': [-122.4271184...
# 3  -122.414584  {'type': 'Point', 'coordinates': [-122.4145837...
# 4  -122.428363  {'type': 'Point', 'coordinates': [-122.4283626...
# 5  -122.429860  {'type': 'Point', 'coordinates': [-122.4298596...
# 6  -122.418885  {'type': 'Point', 'coordinates': [-122.4188852...
# 7  -122.418994  {'type': 'Point', 'coordinates': [-122.4189942...
# 8  -122.406351  {'type': 'Point', 'coordinates': [-122.4063505...
# 9  -122.436116  {'type': 'Point', 'coordinates': [-122.4361164...
# 10 -122.418825  {'type': 'Point', 'coordinates': [-122.4188249...
# 11 -122.436125  {'type': 'Point', 'coordinates': [-122.4361252...
# 12 -122.414404  {'type': 'Point', 'coordinates': [-122.4144037...
# 13 -122.426820  {'type': 'Point', 'coordinates': [-122.4268197...
# 14 -122.433985  {'type': 'Point', 'coordinates': [-122.4339848...
# 15 -122.406354  {'type': 'Point', 'coordinates': [-122.4063540...
# 16 -122.409019  {'type': 'Point', 'coordinates': [-122.4090194...
# 17 -122.430825  {'type': 'Point', 'coordinates': [-122.4308252...
# 18 -122.439439  {'type': 'Point', 'coordinates': [-122.4394387...
# 19 -122.405458  {'type': 'Point', 'coordinates': [-122.4054580...
# 20 -122.434029  {'type': 'Point', 'coordinates': [-122.4340293...
# 21 -122.426217  {'type': 'Point', 'coordinates': [-122.4262169...
# 22 -122.411837  {'type': 'Point', 'coordinates': [-122.4118373...
# 23 -122.411043  {'type': 'Point', 'coordinates': [-122.4110429...
# 24 -122.404373  {'type': 'Point', 'coordinates': [-122.4043731...
# 25 -122.404204  {'type': 'Point', 'coordinates': [-122.4042043...
# 26 -122.440143  {'type': 'Point', 'coordinates': [-122.4401432...
# 27 -122.442234  {'type': 'Point', 'coordinates': [-122.4422342...
# 28 -122.440110  {'type': 'Point', 'coordinates': [-122.44011, ...
# 29 -122.437587  {'type': 'Point', 'coordinates': [-122.4375865...

# %%
df_school.to_json("output/school_info.json", orient="records")
